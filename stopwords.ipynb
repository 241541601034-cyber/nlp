# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download("punkt")
nltk.download("stopwords")
passage = input("Enter the passage: ")
words = word_tokenize(passage)
stop_words = set(stopwords.words("english"))
filtered_words = [word for word in words if word.lower() not in stop_words]
print("Filtered passage:")
print(" ".join(filtered_words))
# Out:
# c:\Users\user\.conda\envs\myenv\Lib\site-packages\nltk\metrics\association.py:26: UserWarning: A NumPy version >=1.22.4 and <2.3.0 is required for this version of SciPy (detected version 2.4.6)
#   from scipy.stats import fisher_exact
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Filtered passage:
# hi nlp

# %%
from nltk import pos_tag
from nltk  import word_tokenize
text="creeks for creeks is a computer science platform"
tokenized_text = word_tokenize(text)
tags = tokens_tag = pos_tag (tokenized_text)
tags
# Out:
# [('creeks', 'NN'),
#  ('for', 'IN'),
#  ('creeks', 'NN'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('computer', 'NN'),
#  ('science', 'NN'),
#  ('platform', 'NN')]

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download("punkt")

def replace_words(sentence, replacements):
    words = word_tokenize(sentence)   # Correct function name
    return ' '.join(replacements.get(word, word) for word in words)

input_sentence = "the quick brown fox jumps over the lazy dog."

replacements = {
    'quick': 'fast',
    'fox': 'wolf',
    'lazy': 'sleepy'
}

print("Replaced sentence:", replace_words(input_sentence, replacements))
# Out:
# Replaced sentence: the fast brown wolf jumps over the sleepy dog .
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
